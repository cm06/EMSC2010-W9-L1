# %% [markdown]
# <a href="https://colab.research.google.com/github/cm06/EMSC2010-W9-L1/blob/main/EMSC2010_W9_L1_NB1_u8257103.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EMSC2010-W9-L1-NB1
# Model Earth's surface temperature (in Kelvin) using a zero-dimensional energy balance model without an atmosphere.
#
# $T_e = \left[ \frac{S}{4 \alpha} (1-A)\right]^{1/4}$
#
# where:
# * $T_e$ is Earth's surface temperature in Kelvin
# * $S$ is the solar flux (1366 W/m$^2$)
# * $A$ is albedo (currently around 0.3)
# * $\alpha$ is the Stefan-Boltmann constant (5.67E-8 W/m$^2$/K$^4$)

# %%
S (solar flux) = 1366 W/m^2
A (albedo) = 0.3
T_e = Earths surface temperature in Kelvin
/alpha = Stefan-Boltmann constant (5.67E-8 W/m^2/K^4)
T_e = ((1366/(4*5.67E-8))*(1-0.3))**(1/4)
print(T_e)
# Out:
# 254.81584054796193

# %%
1399*0.9
# Out:
# 1259.1000000000001

# %%
T_e = ((1259.1000000000001/(4*5.67E-8))*(1-0.3))**(1/4)
print(T_e)
# Out:
# 249.67715293464508
